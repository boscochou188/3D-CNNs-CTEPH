# %%
import os
import zipfile
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers 
from keras.layers import Conv3D, MaxPool3D, Flatten, Dense

model_name = "PE_classification_224_160_48_1_5_i.h5"

# Folder "nr_128_64" consist of CT scans having normal lung tissue or other lung disease

normal_scan_paths2 = [
    os.path.join(os.getcwd(), "C:/Users/85298/AI/PE0415/val/nr", x)
    for x in os.listdir("C:/Users/85298/AI/PE0415/val/nr")
]
# Folder "pe_128_64" consist of CT scans having Pulmonary embolism,

abnormal_scan_paths2 = [
    os.path.join(os.getcwd(),"C:/Users/85298/AI/PE0415/val/pe", x)
    for x in os.listdir("C:/Users/85298/AI/PE0415/val/pe")
]

print("CT scans with normal lung tissue: " + str(len(normal_scan_paths2)))
print("CT scans with abnormal lung tissue: " + str(len(abnormal_scan_paths2)))


####################################################

import nibabel as nib

from scipy import ndimage


def read_nifti_file(filepath):
#   Read and load volume
    # Read file
    scan = nib.load(filepath)
    # Get raw data
    scan = scan.get_fdata()
    return scan


abnormal_scans2 = np.array([read_nifti_file(path) for path in abnormal_scan_paths2])
normal_scans2 = np.array([read_nifti_file(path) for path in normal_scan_paths2])

nr100 = round(len(normal_scan_paths2)  )
pe100 = round(len(abnormal_scan_paths2)   )


#print("nr70%:",nr70,"nr30%",nr30)
#print("pe70%:",pe70,"pe30%:",pe30)

# For the CT scans having Pulmonary embolism
# assign 1, for the normal and other disease ones assign 0.
abnormal_labels2 = np.array([1 for _ in range(len(abnormal_scans2))])
normal_labels2 = np.array([0 for _ in range(len(normal_scans2))])

# Split data in the ratio 70-30 for training and validation.
x_train2 = np.concatenate((abnormal_scans2[:pe100], normal_scans2[:nr100]), axis=0)
y_train2 = np.concatenate((abnormal_labels2[:pe100], normal_labels2[:nr100]), axis=0)
x_val2 = np.concatenate((abnormal_scans2[pe100:], normal_scans2[nr100:]), axis=0)
y_val2 = np.concatenate((abnormal_labels2[pe100:], normal_labels2[nr100:]), axis=0)
print(
    "Number of samples in train and validation are %d and %d."
    % (x_train2.shape[0], x_val2.shape[0])
)
# Out:
# CT scans with normal lung tissue: 33
# CT scans with abnormal lung tissue: 7
# Number of samples in train and validation are 40 and 0.

# %%
from keras.utils import np_utils
from keras.layers import Conv3D, MaxPool3D, Flatten, Dense
from keras.layers import Dropout, Input, BatchNormalization
from sklearn.metrics import confusion_matrix, accuracy_score
from keras.losses import binary_crossentropy
from keras.optimizers import Adadelta, SGD
from matplotlib.pyplot import cm
import matplotlib.pyplot as plt
from keras.models import Model
import cv2
import time
import os
import numpy as np
import keras
import h5py
import numpy as np
from keras import regularizers
import os
import glob
import cv2
import random
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_curve, roc_auc_score
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping, ReduceLROnPlateau
from keras.models import Sequential
from keras.optimizers import RMSprop
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from keras import optimizers
from keras.utils import to_categorical, plot_model
from keras.layers import Dense, Input, Conv2D, Flatten, MaxPooling2D, Activation
from keras.models import Model, Sequential
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam
from keras.applications.vgg16 import VGG16
from keras.models import load_model
from keras.utils import np_utils
from keras import backend as K
from keras.models import load_model
import keras
import tensorflow as tf

def get_model():
    
    input_layer = Input((224, 160, 48, 1))
    
    conv_layer1 = Conv3D(filters=128, kernel_size=(3, 3, 3), activation='relu')(input_layer)
    pooling_layer1 = MaxPool3D(pool_size=(2, 2, 2))(conv_layer1)
    pooling_layer1 = BatchNormalization()(pooling_layer1) 
#    pooling_layer1 = Dropout(0.5)(pooling_layer1)  
    
    
    conv_layer2 = Conv3D(filters=256, kernel_size=(3, 3, 3), activation='relu')(pooling_layer1)
    pooling_layer2 = MaxPool3D(pool_size=(2, 2, 2))(conv_layer2)
    pooling_layer2 = BatchNormalization()(pooling_layer2)  
#    pooling_layer2 = Dropout(0.5)(pooling_layer2)
    
    conv_layer3 = Conv3D(filters=512, kernel_size=(3, 3, 3), activation='relu')(pooling_layer2)
    pooling_layer3 = MaxPool3D(pool_size=(2, 2, 2))(conv_layer3)
    pooling_layer3 = BatchNormalization()(pooling_layer3)
#    pooling_layer3 = Dropout(0.5)(pooling_layer3)
    
    conv_layer4 = Conv3D(filters=1024, kernel_size=(3, 3, 3), activation='relu')(pooling_layer3)
    pooling_layer4 = MaxPool3D(pool_size=(2, 2, 2))(conv_layer4)
    pooling_layer4 = BatchNormalization()(pooling_layer4)
#    pooling_layer4 = Dropout(0.5)(pooling_layer4)
    
    flatten_layer = Flatten()(pooling_layer4)
    

    dense_layer4 = Dense(units=2048, activation='relu')( flatten_layer)
    dense_layer4 = Dropout(0.4)(dense_layer4)
    
    
    dense_layer5 = Dense(units=1024, activation='relu')(dense_layer4)
    dense_layer5 = Dropout(0.4)(dense_layer5)
    

    output_layer = Dense(units=1, activation="sigmoid")(dense_layer5)
    

    model = Model(inputs=input_layer, outputs=output_layer, name="3dcnn")


    
    return model

model = None
model = get_model()
model.summary()
# Out:
# Model: "3dcnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 160, 48, 1)  0
#                              ]
#
#  conv3d (Conv3D)             (None, 222, 158, 46, 128  3584
#                              )
#
#  max_pooling3d (MaxPooling3D  (None, 111, 79, 23, 128)  0
#  )
#
#  batch_normalization (BatchN  (None, 111, 79, 23, 128)  512
#  ormalization)
#
#  conv3d_1 (Conv3D)           (None, 109, 77, 21, 256)  884992
#
#  max_pooling3d_1 (MaxPooling  (None, 54, 38, 10, 256)  0
#  3D)
#
#  batch_normalization_1 (Batc  (None, 54, 38, 10, 256)  1024
#  hNormalization)
#
#  conv3d_2 (Conv3D)           (None, 52, 36, 8, 512)    3539456
#
#  max_pooling3d_2 (MaxPooling  (None, 26, 18, 4, 512)   0
#  3D)
#
#  batch_normalization_2 (Batc  (None, 26, 18, 4, 512)   2048
#  hNormalization)
#
#  conv3d_3 (Conv3D)           (None, 24, 16, 2, 1024)   14156800
#
#  max_pooling3d_3 (MaxPooling  (None, 12, 8, 1, 1024)   0
#  3D)
#
#  batch_normalization_3 (Batc  (None, 12, 8, 1, 1024)   4096
#  hNormalization)
#
#  flatten (Flatten)           (None, 98304)             0
#
#  dense (Dense)               (None, 2048)              201328640
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1024)              2098176
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 222,020,353
# Trainable params: 222,016,513
# Non-trainable params: 3,840
# _________________________________________________________________

# %%
import warnings 
warnings.simplefilter(action='ignore',category=FutureWarning)

# %%
import numpy as np
import pandas as pd
import csv
from keras.models import load_model

df_label = pd.read_csv('C:/Users/85298/AI/CT_image/202304/label_cut_d.csv' , sep=',')
y=df_label.set_index("ID3", inplace = True)


df_out = pd.DataFrame(columns = ["ID","Disease","Label","predict", "actual"])
df_out2 = pd.DataFrame(columns = ["predict", "actual"])

len_nr = len(normal_scan_paths2)
len_pe = len(abnormal_scan_paths2)


for patient in range (0,len(y_train2)):

#for patient in range (0,20):
    
    if patient < len_pe:
    
        file_path = abnormal_scan_paths2[patient]
    
    else :
        
        file_path = normal_scan_paths2 [patient-len_pe]
        
    ID = file_path.split("_") [2]


    
    Disease = df_label.loc[int(ID)]["Disease"]    

    Label = df_label.loc[int(ID)]["Label"] 
    

    

# Load best weights.


    model.load_weights(model_name)
    prediction = model.predict(np.expand_dims(x_train2[patient], axis=0))[0]
    label_1 = y_train2[patient]
    
    scores = [1 - prediction[0], prediction[0]]
 #   print(label_1)
     
    prediction_score = round(prediction[0] *100,2)
    prediction_score2 = prediction[0] *100
        
    df_out = df_out.append({"ID": ID,"Disease":Disease,"Label":Label ,'predict' : prediction_score , 'actual' : label_1 },
        ignore_index = True)

    df_out2 = df_out2.append({'predict' : prediction_score2 , 'actual' : label_1 },
        ignore_index = True)
    
    
print(df_out)
# Out:
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
#       ID                                       Disease  Label  predict actual
# 0   1017                                            PE     PE     1.41      1
# 1   3005                                    Chronic PE     PE   100.00      1
# 2   3029                                    Chronic PE     PE    99.99      1
# 3   4059                    Pulmonary embolism present     PE   100.00      1
# 4   5005         Non diagnostic for pulmonary embolism     PE     7.55      1
# 5   6022                                 Nondiagnostic     PE     0.04      1
# 6   6032                                 Nondiagnostic     PE   100.00      1
# 7   1000                                            PH  OTHER     5.79      0
# 8   1004                                            PH  OTHER     2.51      0
# 9   1007                                            PH  OTHER     0.01      0
# 10  1008                                            PH  OTHER    19.04      0
# 11  1015                                    Chest pain  OTHER     2.69      0
# 12  1023                                        Normal  OTHER     0.00      0
# 13  1024                      Hepatopulmonary syndrome  OTHER     0.00      0
# 14  2009                              Cancer carcinoma  OTHER    84.78      0
# 15  2013                  Systemic lupus erythematosus  OTHER     1.63      0
# 16  3006                                            PH  OTHER     0.00      0
# 17  3011                                        Normal  OTHER     3.08      0
# 18  3021                                            PH  OTHER     0.00      0
# 19  3026  Deep venous thrombosis/Myocardial infarction  OTHER     0.00      0
# 20  4001                        Pulmonary hypertension  OTHER     0.02      0
# 21  4002                     Pulmonary embolism absent  OTHER     0.00      0
# 22  4006                        Pulmonary hypertension  OTHER     6.03      0
# 23  4008                     Pulmonary embolism absent  OTHER     0.00      0
# 24  4018                        Pulmonary hypertension  OTHER     0.17      0
# 25  4020                      Pulmonary leiomyosarcoma  OTHER     1.15      0
# 26  4021                     Pulmonary embolism absent  OTHER     0.14      0
# 27  4023                                        Normal  OTHER     0.00      0
# 28  4035                               Lung metastases  OTHER     0.00      0
# 29  4043                             Carcinoma of lung  OTHER     0.00      0
# 30  4055                     Pulmonary embolism absent  OTHER     0.00      0
# 31  4057                        Pulmonary angiosarcoma  OTHER     5.74      0
# 32  4058                        Pulmonary hypertension  OTHER     0.00      0
# 33  5014                     Pulmonary embolism absent  OTHER    16.51      0
# 34  6002                                        Absent  OTHER     1.94      0
# 35  6003                                        Absent  OTHER     0.00      0
# 36  6006                                       Ca Lung  OTHER    26.47      0
# 37  6010                                        Absent  OTHER     0.00      0
# 38  6019                                        Absent  OTHER     0.00      0
# 39  6030                                        Absent  OTHER     0.00      0

# %%
import numpy as np
import pandas as pd
import csv
from keras.models import load_model

for i in np.arange (1,99,1):
    
    i = round(i,2)

    TP = 0
    FP = 0
    TN = 0
    FN = 0


    for patient in range (0,len(df_out)):
    

        if (df_out["predict"].iloc[patient] > i) & (df_out["actual"].iloc[patient] == 1) :
            TP = TP + 1
        if (df_out["predict"].iloc[patient] > i) & (df_out["actual"].iloc[patient] == 0) :
            FP = FP + 1
        if (df_out["predict"].iloc[patient] < i) & (df_out["actual"].iloc[patient] == 0) :
            TN = TN + 1
        if (df_out["predict"].iloc[patient] < i) & (df_out["actual"].iloc[patient] == 1) :
            FN = FN + 1        
        

    Precision = TP/(TP+FP)

    Recall = TP/(TP+FN)

    F1_score = ((Precision*Recall)/(Precision+Recall))*2

    Accuracy = (TP+TN)/(TP+FP+TN+FN)
    print(str(i))
    print ("Precision",round(Precision,2),"Recall",round(Recall,2),"F1_score",round(F1_score,2),"Accuracy",round(Accuracy,2))
    print ("TP",TP,"FP",FP,"TN",TN,"FN",FN)
# Out:
# 1
# Precision 0.32 Recall 0.86 F1_score 0.46 Accuracy 0.65
# TP 6 FP 13 TN 20 FN 1
# 2
# Precision 0.33 Recall 0.71 F1_score 0.45 Accuracy 0.7
# TP 5 FP 10 TN 23 FN 2
# 3
# Precision 0.38 Recall 0.71 F1_score 0.5 Accuracy 0.75
# TP 5 FP 8 TN 25 FN 2
# 4
# Precision 0.42 Recall 0.71 F1_score 0.53 Accuracy 0.78
# TP 5 FP 7 TN 26 FN 2
# 5
# Precision 0.42 Recall 0.71 F1_score 0.53 Accuracy 0.78
# TP 5 FP 7 TN 26 FN 2
# 6
# Precision 0.5 Recall 0.71 F1_score 0.59 Accuracy 0.82
# TP 5 FP 5 TN 28 FN 2
# 7
# Precision 0.56 Recall 0.71 F1_score 0.63 Accuracy 0.85
# TP 5 FP 4 TN 29 FN 2
# 8
# Precision 0.5 Recall 0.57 F1_score 0.53 Accuracy 0.82
# TP 4 FP 4 TN 29 FN 3
# 9
# Precision 0.5 Recall 0.57 F1_score 0.53 Accuracy 0.82
# TP 4 FP 4 TN 29 FN 3
# 10
# Precision 0.5 Recall 0.57 F1_score 0.53 Accuracy 0.82
# TP 4 FP 4 TN 29 FN 3
# 11
# Precision 0.5 Recall 0.57 F1_score 0.53 Accuracy 0.82
# TP 4 FP 4 TN 29 FN 3
# 12
# Precision 0.5 Recall 0.57 F1_score 0.53 Accuracy 0.82
# TP 4 FP 4 TN 29 FN 3
# 13
# Precision 0.5 Recall 0.57 F1_score 0.53 Accuracy 0.82
# TP 4 FP 4 TN 29 FN 3
# 14
# Precision 0.5 Recall 0.57 F1_score 0.53 Accuracy 0.82
# TP 4 FP 4 TN 29 FN 3
# 15
# Precision 0.5 Recall 0.57 F1_score 0.53 Accuracy 0.82
# TP 4 FP 4 TN 29 FN 3
# 16
# Precision 0.5 Recall 0.57 F1_score 0.53 Accuracy 0.82
# TP 4 FP 4 TN 29 FN 3
# 17
# Precision 0.57 Recall 0.57 F1_score 0.57 Accuracy 0.85
# TP 4 FP 3 TN 30 FN 3
# 18
# Precision 0.57 Recall 0.57 F1_score 0.57 Accuracy 0.85
# TP 4 FP 3 TN 30 FN 3
# 19
# Precision 0.57 Recall 0.57 F1_score 0.57 Accuracy 0.85
# TP 4 FP 3 TN 30 FN 3
# 20
# Precision 0.67 Recall 0.57 F1_score 0.62 Accuracy 0.88
# TP 4 FP 2 TN 31 FN 3
# 21
# Precision 0.67 Recall 0.57 F1_score 0.62 Accuracy 0.88
# TP 4 FP 2 TN 31 FN 3
# 22
# Precision 0.67 Recall 0.57 F1_score 0.62 Accuracy 0.88
# TP 4 FP 2 TN 31 FN 3
# 23
# Precision 0.67 Recall 0.57 F1_score 0.62 Accuracy 0.88
# TP 4 FP 2 TN 31 FN 3
# 24
# Precision 0.67 Recall 0.57 F1_score 0.62 Accuracy 0.88
# TP 4 FP 2 TN 31 FN 3
# 25
# Precision 0.67 Recall 0.57 F1_score 0.62 Accuracy 0.88
# TP 4 FP 2 TN 31 FN 3
# 26
# Precision 0.67 Recall 0.57 F1_score 0.62 Accuracy 0.88
# TP 4 FP 2 TN 31 FN 3
# 27
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 28
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 29
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 30
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 31
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 32
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 33
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 34
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 35
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 36
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 37
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 38
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 39
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 40
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 41
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 42
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 43
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 44
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 45
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 46
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 47
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 48
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 49
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 50
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 51
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 52
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 53
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 54
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 55
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 56
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 57
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 58
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 59
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 60
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 61
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 62
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 63
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 64
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 65
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 66
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 67
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 68
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 69
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 70
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 71
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 72
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 73
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 74
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 75
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 76
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 77
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 78
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 79
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 80
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 81
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 82
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 83
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 84
# Precision 0.8 Recall 0.57 F1_score 0.67 Accuracy 0.9
# TP 4 FP 1 TN 32 FN 3
# 85
# Precision 1.0 Recall 0.57 F1_score 0.73 Accuracy 0.93
# TP 4 FP 0 TN 33 FN 3
# 86
# Precision 1.0 Recall 0.57 F1_score 0.73 Accuracy 0.93
# TP 4 FP 0 TN 33 FN 3
# 87
# Precision 1.0 Recall 0.57 F1_score 0.73 Accuracy 0.93
# TP 4 FP 0 TN 33 FN 3
# 88
# Precision 1.0 Recall 0.57 F1_score 0.73 Accuracy 0.93
# TP 4 FP 0 TN 33 FN 3
# 89
# Precision 1.0 Recall 0.57 F1_score 0.73 Accuracy 0.93
# TP 4 FP 0 TN 33 FN 3
# 90
# Precision 1.0 Recall 0.57 F1_score 0.73 Accuracy 0.93
# TP 4 FP 0 TN 33 FN 3
# 91
# Precision 1.0 Recall 0.57 F1_score 0.73 Accuracy 0.93
# TP 4 FP 0 TN 33 FN 3
# 92
# Precision 1.0 Recall 0.57 F1_score 0.73 Accuracy 0.93
# TP 4 FP 0 TN 33 FN 3
# 93
# Precision 1.0 Recall 0.57 F1_score 0.73 Accuracy 0.93
# TP 4 FP 0 TN 33 FN 3
# 94
# Precision 1.0 Recall 0.57 F1_score 0.73 Accuracy 0.93
# TP 4 FP 0 TN 33 FN 3
# 95
# Precision 1.0 Recall 0.57 F1_score 0.73 Accuracy 0.93
# TP 4 FP 0 TN 33 FN 3
# 96
# Precision 1.0 Recall 0.57 F1_score 0.73 Accuracy 0.93
# TP 4 FP 0 TN 33 FN 3
# 97
# Precision 1.0 Recall 0.57 F1_score 0.73 Accuracy 0.93
# TP 4 FP 0 TN 33 FN 3
# 98
# Precision 1.0 Recall 0.57 F1_score 0.73 Accuracy 0.93
# TP 4 FP 0 TN 33 FN 3

# %%
import numpy as np
import pandas as pd
import csv
from keras.models import load_model

for i in np.arange (85,86,1):
    
    i = round(i,2)

    TP = 0
    FP = 0
    TN = 0
    FN = 0


    for patient in range (0,len(df_out)):
    

        if (df_out["predict"].iloc[patient] > i) & (df_out["actual"].iloc[patient] == 1) :
            TP = TP + 1
        if (df_out["predict"].iloc[patient] > i) & (df_out["actual"].iloc[patient] == 0) :
            FP = FP + 1
        if (df_out["predict"].iloc[patient] < i) & (df_out["actual"].iloc[patient] == 0) :
            TN = TN + 1
        if (df_out["predict"].iloc[patient] < i) & (df_out["actual"].iloc[patient] == 1) :
            FN = FN + 1        
        

    Precision = TP/(TP+FP)

    Recall = TP/(TP+FN)

    F1_score = ((Precision*Recall)/(Precision+Recall))*2

    Accuracy = (TP+TN)/(TP+FP+TN+FN)
    print(str(i))
    print ("Precision",round(Precision,2),"Recall",round(Recall,2),"F1_score",round(F1_score,2),"Accuracy",round(Accuracy,2))
    print ("TP",TP,"FP",FP,"TN",TN,"FN",FN)
# Out:
# 85
# Precision 1.0 Recall 0.57 F1_score 0.73 Accuracy 0.93
# TP 4 FP 0 TN 33 FN 3

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
#Y_pred = model.predict(x_val)
disease_types=['PE', 'non-PE']



#Y_pred = np.argmax(Y_pred, axis=1)
#Y_true = y_val
#Y_true = np.argmax(y_val,axis=1)
#print (Y_pred)
#print (Y_true)
#cm = confusion_matrix(Y_true, Y_pred)

cm = [[TP,FN],[FP,TN]]

plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap=plt.cm.Greens, annot=True, square=True, xticklabels=disease_types, yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=40)
ax.set_xlabel('Predicted', fontsize=40)
# Out:
# Text(0.5, 192.72222222222217, 'Predicted')

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score, auc

# 讀取資料
import pandas as pd
#df=pd.read_csv('./AUC.csv')

# 在各種『決策門檻』（decision threshold）下，計算 『真陽率』（True Positive Rate；TPR）與『假陽率』（False Positive Rate；FPR）
fpr, tpr, threshold = roc_curve(df_out2['actual'], df_out2['predict'])
print(fpr, tpr, threshold)

auc1 = auc(fpr, tpr)
## Plot the result
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, color = 'orange', label = 'AUC = %0.2f' % auc1)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# [0.         0.         0.         0.12121212 0.12121212 0.36363636
#  0.36363636 0.45454545 0.45454545 1.        ] [0.         0.14285714 0.57142857 0.57142857 0.71428571 0.71428571
#  0.85714286 0.85714286 1.         1.        ] [1.01000000e+02 1.00000000e+02 9.99916434e+01 1.65098891e+01
#  7.54798427e+00 1.63145568e+00 1.41100176e+00 1.40649616e-01
#  4.40927892e-02 3.26551417e-15]
